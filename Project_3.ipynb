# %%
#Imports

import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
#Sample API request, will need to be dynamic

response = requests.get('https://sandbox.tradier.com/v1/markets/history',
    params={'symbol': 'MSFT', 'interval': 'daily', 'start': '2018-01-01', 'end': '2020-03-06'},
    headers={'Authorization': 'Bearer IGef006CVwMc97oonnuCq28ce1dK', 'Accept': 'application/json'}
)
json_response = response.json()

json_response
# Out:
# {'history': {'day': [{'date': '2018-01-02',
#     'open': 86.125,
#     'high': 86.31,
#     'low': 85.5,
#     'close': 85.95,
#     'volume': 22483797},
#    {'date': '2018-01-03',
#     'open': 86.055,
#     'high': 86.51,
#     'low': 85.97,
#     'close': 86.35,
#     'volume': 26061439},
#    {'date': '2018-01-04',
#     'open': 86.59,
#     'high': 87.66,
#     'low': 86.57,
#     'close': 87.11,
#     'volume': 21911974},
#    {'date': '2018-01-05',
#     'open': 87.66,
#     'high': 88.41,
#     'low': 87.43,
#     'close': 88.19,
#     'volume': 23407110},
#    {'date': '2018-01-08',
#     'open': 88.2,
#     'high': 88.58,
#     'low': 87.6046,
#     'close': 88.28,
#     'volume': 22113049},
#    {'date': '2018-01-09',
#     'open': 88.65,
#     'high': 88.7272,
#     'low': 87.86,
#     'close': 88.22,
#     'volume': 19484317},
#    {'date': '2018-01-10',
#     'open': 87.86,
#     'high': 88.19,
#     'low': 87.41,
#     'close': 87.82,
#     'volume': 18652201},
#    {'date': '2018-01-11',
#     'open': 88.13,
#     'high': 88.13,
#     'low': 87.24,
#     'close': 88.08,
#     'volume': 17808877},
#    {'date': '2018-01-12',
#     'open': 88.67,
#     'high': 89.78,
#     'low': 88.45,
#     'close': 89.6,
#     'volume': 24271531},
#    {'date': '2018-01-16',
#     'open': 90.1,
#     'high': 90.79,
#     'low': 88.0104,
#     'close': 88.35,
#     'volume': 36599736},
#    {'date': '2018-01-17',
#     'open': 89.08,
#     'high': 90.28,
#     'low': 88.75,
#     'close': 90.14,
#     'volume': 25621164},
#    {'date': '2018-01-18',
#     'open': 89.8,
#     'high': 90.67,
#     'low': 89.66,
#     'close': 90.1,
#     'volume': 24159683},
#    {'date': '2018-01-19',
#     'open': 90.14,
#     'high': 90.61,
#     'low': 89.66,
#     'close': 90.0,
#     'volume': 36875013},
#    {'date': '2018-01-22',
#     'open': 90.0,
#     'high': 91.62,
#     'low': 89.74,
#     'close': 91.61,
#     'volume': 23601555},
#    {'date': '2018-01-23',
#     'open': 91.9,
#     'high': 92.3,
#     'low': 91.54,
#     'close': 91.9,
#     'volume': 23412841},
#    {'date': '2018-01-24',
#     'open': 92.55,
#     'high': 93.43,
#     'low': 91.58,
#     'close': 91.82,
#     'volume': 33278178},
#    {'date': '2018-01-25',
#     'open': 92.465,
#     'high': 93.24,
#     'low': 91.93,
#     'close': 92.33,
#     'volume': 26383238},
#    {'date': '2018-01-26',
#     'open': 93.12,
#     'high': 94.06,
#     'low': 92.58,
#     'close': 94.06,
#     'volume': 29172167},
#    {'date': '2018-01-29',
#     'open': 95.14,
#     'high': 95.45,
#     'low': 93.72,
#     'close': 93.92,
#     'volume': 31569940},
#    {'date': '2018-01-30',
#     'open': 93.3,
#     'high': 93.66,
#     'low': 92.1,
#     'close': 92.74,
#     'volume': 38635053},
#    {'date': '2018-01-31',
#     'open': 93.75,
#     'high': 95.4,
#     'low': 93.51,
#     'close': 95.01,
#     'volume': 48756338},
#    {'date': '2018-02-01',
#     'open': 94.79,
#     'high': 96.07,
#     'low': 93.5813,
#     'close': 94.26,
#     'volume': 47227882},
#    {'date': '2018-02-02',
#     'open': 93.64,
#     'high': 93.97,
#     'low': 91.5,
#     'close': 91.78,
#     'volume': 47867753},
#    {'date': '2018-02-05',
#     'open': 90.56,
#     'high': 93.24,
#     'low': 88.0,
#     'close': 88.0,
#     'volume': 51031465},
#    {'date': '2018-02-06',
#     'open': 86.89,
#     'high': 91.475,
#     'low': 85.25,
#     'close': 91.33,
#     'volume': 67998564},
#    {'date': '2018-02-07',
#     'open': 90.49,
#     'high': 91.77,
#     'low': 89.2,
#     'close': 89.61,
#     'volume': 41107592},
#    {'date': '2018-02-08',
#     'open': 89.71,
#     'high': 89.875,
#     'low': 84.76,
#     'close': 85.01,
#     'volume': 55628657},
#    {'date': '2018-02-09',
#     'open': 86.3,
#     'high': 88.93,
#     'low': 83.83,
#     'close': 88.18,
#     'volume': 63499065},
#    {'date': '2018-02-12',
#     'open': 88.735,
#     'high': 89.78,
#     'low': 87.9295,
#     'close': 89.13,
#     'volume': 35720341},
#    {'date': '2018-02-13',
#     'open': 88.93,
#     'high': 90.0,
#     'low': 87.8,
#     'close': 89.83,
#     'volume': 26407702},
#    {'date': '2018-02-14',
#     'open': 88.51,
#     'high': 90.99,
#     'low': 88.41,
#     'close': 90.81,
#     'volume': 34960912},
#    {'date': '2018-02-15',
#     'open': 91.21,
#     'high': 92.72,
#     'low': 90.62,
#     'close': 92.66,
#     'volume': 27823866},
#    {'date': '2018-02-16',
#     'open': 92.45,
#     'high': 93.5,
#     'low': 91.8,
#     'close': 92.0,
#     'volume': 30596919},
#    {'date': '2018-02-20',
#     'open': 91.475,
#     'high': 93.06,
#     'low': 91.01,
#     'close': 92.72,
#     'volume': 30911725},
#    {'date': '2018-02-21',
#     'open': 92.98,
#     'high': 93.3595,
#     'low': 91.49,
#     'close': 91.49,
#     'volume': 26922503},
#    {'date': '2018-02-22',
#     'open': 92.05,
#     'high': 92.73,
#     'low': 91.36,
#     'close': 91.73,
#     'volume': 24392753},
#    {'date': '2018-02-23',
#     'open': 92.75,
#     'high': 94.07,
#     'low': 92.36,
#     'close': 94.06,
#     'volume': 26329226},
#    {'date': '2018-02-26',
#     'open': 94.4,
#     'high': 95.45,
#     'low': 94.25,
#     'close': 95.42,
#     'volume': 30199846},
#    {'date': '2018-02-27',
#     'open': 95.74,
#     'high': 95.84,
#     'low': 94.2,
#     'close': 94.2,
#     'volume': 25869119},
#    {'date': '2018-02-28',
#     'open': 94.84,
#     'high': 95.705,
#     'low': 93.63,
#     'close': 93.77,
#     'volume': 31167338},
#    {'date': '2018-03-01',
#     'open': 93.99,
#     'high': 94.57,
#     'low': 91.84,
#     'close': 92.85,
#     'volume': 37135561},
#    {'date': '2018-03-02',
#     'open': 91.58,
#     'high': 93.15,
#     'low': 90.86,
#     'close': 93.05,
#     'volume': 32830389},
#    {'date': '2018-03-05',
#     'open': 92.34,
#     'high': 94.27,
#     'low': 92.26,
#     'close': 93.64,
#     'volume': 23901578},
#    {'date': '2018-03-06',
#     'open': 94.34,
#     'high': 94.49,
#     'low': 92.941,
#     'close': 93.32,
#     'volume': 22175776},
#    {'date': '2018-03-07',
#     'open': 93.16,
#     'high': 93.9406,
#     'low': 92.43,
#     'close': 93.86,
#     'volume': 26716127},
#    {'date': '2018-03-08',
#     'open': 94.27,
#     'high': 95.1,
#     'low': 93.765,
#     'close': 94.43,
#     'volume': 25887828},
#    {'date': '2018-03-09',
#     'open': 95.29,
#     'high': 96.54,
#     'low': 95.0,
#     'close': 96.54,
#     'volume': 36937254},
#    {'date': '2018-03-12',
#     'open': 96.5,
#     'high': 97.21,
#     'low': 96.04,
#     'close': 96.77,
#     'volume': 26073742},
#    {'date': '2018-03-13',
#     'open': 97.0,
#     'high': 97.24,
#     'low': 93.97,
#     'close': 94.41,
#     'volume': 35387817},
#    {'date': '2018-03-14',
#     'open': 95.12,
#     'high': 95.41,
#     'low': 93.5,
#     'close': 93.85,
#     'volume': 32131981},
#    {'date': '2018-03-15',
#     'open': 93.53,
#     'high': 94.58,
#     'low': 92.83,
#     'close': 94.18,
#     'volume': 27610998},
#    {'date': '2018-03-16',
#     'open': 94.68,
#     'high': 95.38,
#     'low': 93.92,
#     'close': 94.6,
#     'volume': 49081279},
#    {'date': '2018-03-19',
#     'open': 93.74,
#     'high': 93.9,
#     'low': 92.11,
#     'close': 92.89,
#     'volume': 33344085},
#    {'date': '2018-03-20',
#     'open': 93.05,
#     'high': 93.77,
#     'low': 93.0,
#     'close': 93.13,
#     'volume': 23075240},
#    {'date': '2018-03-21',
#     'open': 92.93,
#     'high': 94.05,
#     'low': 92.21,
#     'close': 92.48,
#     'volume': 24457082},
#    {'date': '2018-03-22',
#     'open': 91.265,
#     'high': 91.75,
#     'low': 89.66,
#     'close': 89.79,
#     'volume': 38604715},
#    {'date': '2018-03-23',
#     'open': 89.5,
#     'high': 90.46,
#     'low': 87.08,
#     'close': 87.18,
#     'volume': 44068949},
#    {'date': '2018-03-26',
#     'open': 90.61,
#     'high': 94.0,
#     'low': 90.4,
#     'close': 93.78,
#     'volume': 56396780},
#    {'date': '2018-03-27',
#     'open': 94.94,
#     'high': 95.139,
#     'low': 88.51,
#     'close': 89.47,
#     'volume': 56569011},
#    {'date': '2018-03-28',
#     'open': 89.82,
#     'high': 91.23,
#     'low': 88.873,
#     'close': 89.39,
#     'volume': 52501146},
#    {'date': '2018-03-29',
#     'open': 90.18,
#     'high': 92.29,
#     'low': 88.4,
#     'close': 91.27,
#     'volume': 45867548},
#    {'date': '2018-04-02',
#     'open': 90.47,
#     'high': 90.88,
#     'low': 87.51,
#     'close': 88.52,
#     'volume': 48515417},
#    {'date': '2018-04-03',
#     'open': 89.575,
#     'high': 90.05,
#     'low': 87.89,
#     'close': 89.71,
#     'volume': 37213837},
#    {'date': '2018-04-04',
#     'open': 87.85,
#     'high': 92.76,
#     'low': 87.73,
#     'close': 92.33,
#     'volume': 35559956},
#    {'date': '2018-04-05',
#     'open': 92.435,
#     'high': 93.065,
#     'low': 91.4,
#     'close': 92.38,
#     'volume': 29771881},
#    {'date': '2018-04-06',
#     'open': 91.49,
#     'high': 92.46,
#     'low': 89.48,
#     'close': 90.23,
#     'volume': 38026000},
#    {'date': '2018-04-09',
#     'open': 91.04,
#     'high': 93.17,
#     'low': 90.62,
#     'close': 90.77,
#     'volume': 31533943},
#    {'date': '2018-04-10',
#     'open': 92.39,
#     'high': 93.28,
#     'low': 91.64,
#     'close': 92.88,
#     'volume': 26939883},
#    {'date': '2018-04-11',
#     'open': 92.01,
#     'high': 93.29,
#     'low': 91.48,
#     'close': 91.86,
#     'volume': 24872110},
#    {'date': '2018-04-12',
#     'open': 92.43,
#     'high': 94.16,
#     'low': 92.43,
#     'close': 93.58,
#     'volume': 26758879},
#    {'date': '2018-04-13',
#     'open': 94.05,
#     'high': 94.18,
#     'low': 92.44,
#     'close': 93.08,
#     'volume': 23346063},
#    {'date': '2018-04-16',
#     'open': 94.07,
#     'high': 94.66,
#     'low': 93.42,
#     'close': 94.17,
#     'volume': 20288083},
#    {'date': '2018-04-17',
#     'open': 95.0,
#     'high': 96.54,
#     'low': 94.88,
#     'close': 96.07,
#     'volume': 26771000},
#    {'date': '2018-04-18',
#     'open': 96.22,
#     'high': 96.72,
#     'low': 95.52,
#     'close': 96.44,
#     'volume': 21043287},
#    {'date': '2018-04-19',
#     'open': 96.44,
#     'high': 97.07,
#     'low': 95.34,
#     'close': 96.11,
#     'volume': 23552541},
#    {'date': '2018-04-20',
#     'open': 95.91,
#     'high': 96.11,
#     'low': 94.05,
#     'close': 95.0,
#     'volume': 31154377},
#    {'date': '2018-04-23',
#     'open': 95.7436,
#     'high': 96.29,
#     'low': 94.63,
#     'close': 95.35,
#     'volume': 22331829},
#    {'date': '2018-04-24',
#     'open': 96.242,
#     'high': 96.47,
#     'low': 92.41,
#     'close': 93.12,
#     'volume': 34524799},
#    {'date': '2018-04-25',
#     'open': 93.3,
#     'high': 93.3,
#     'low': 90.28,
#     'close': 92.31,
#     'volume': 33729257},
#    {'date': '2018-04-26',
#     'open': 93.55,
#     'high': 95.15,
#     'low': 93.1,
#     'close': 94.26,
#     'volume': 42529043},
#    {'date': '2018-04-27',
#     'open': 97.6,
#     'high': 97.9,
#     'low': 93.91,
#     'close': 95.82,
#     'volume': 48272780},
#    {'date': '2018-04-30',
#     'open': 96.33,
#     'high': 96.3964,
#     'low': 93.15,
#     'close': 93.52,
#     'volume': 41523605},
#    {'date': '2018-05-01',
#     'open': 93.21,
#     'high': 95.29,
#     'low': 92.79,
#     'close': 95.0,
#     'volume': 31408927},
#    {'date': '2018-05-02',
#     'open': 94.99,
#     'high': 95.17,
#     'low': 93.19,
#     'close': 93.51,
#     'volume': 27471002},
#    {'date': '2018-05-03',
#     'open': 92.96,
#     'high': 94.925,
#     'low': 92.45,
#     'close': 94.07,
#     'volume': 31142497},
#    {'date': '2018-05-04',
#     'open': 93.32,
#     'high': 95.37,
#     'low': 92.92,
#     'close': 95.16,
#     'volume': 22531325},
#    {'date': '2018-05-07',
#     'open': 95.17,
#     'high': 96.71,
#     'low': 95.1,
#     'close': 96.22,
#     'volume': 24242019},
#    {'date': '2018-05-08',
#     'open': 95.8456,
#     'high': 96.16,
#     'low': 95.0631,
#     'close': 95.81,
#     'volume': 23484589},
#    {'date': '2018-05-09',
#     'open': 96.01,
#     'high': 96.97,
#     'low': 95.05,
#     'close': 96.94,
#     'volume': 27327410},
#    {'date': '2018-05-10',
#     'open': 97.46,
#     'high': 97.95,
#     'low': 97.05,
#     'close': 97.91,
#     'volume': 22388119},
#    {'date': '2018-05-11',
#     'open': 97.8,
#     'high': 97.87,
#     'low': 97.04,
#     'close': 97.7,
#     'volume': 16778316},
#    {'date': '2018-05-14',
#     'open': 97.92,
#     'high': 98.69,
#     'low': 97.31,
#     'close': 98.03,
#     'volume': 19454124},
#    {'date': '2018-05-15',
#     'open': 97.24,
#     'high': 97.85,
#     'low': 96.34,
#     'close': 97.32,
#     'volume': 24594010},
#    {'date': '2018-05-16',
#     'open': 97.36,
#     'high': 97.4,
#     'low': 96.615,
#     'close': 97.15,
#     'volume': 17384742},
#    {'date': '2018-05-17',
#     'open': 96.76,
#     'high': 97.5401,
#     'low': 95.83,
#     'close': 96.18,
#     'volume': 17246716},
#    {'date': '2018-05-18',
#     'open': 96.01,
#     'high': 96.93,
#     'low': 96.01,
#     'close': 96.36,
#     'volume': 17865840},
#    {'date': '2018-05-21',
#     'open': 97.0,
#     'high': 98.01,
#     'low': 96.8,
#     'close': 97.6,
#     'volume': 19422467},
#    {'date': '2018-05-22',
#     'open': 97.68,
#     'high': 98.17,
#     'low': 97.2,
#     'close': 97.5,
#     'volume': 15441189},
#    {'date': '2018-05-23',
#     'open': 96.71,
#     'high': 98.73,
#     'low': 96.32,
#     'close': 98.66,
#     'volume': 21251222},
#    {'date': '2018-05-24',
#     'open': 98.725,
#     'high': 98.94,
#     'low': 96.81,
#     'close': 98.31,
#     'volume': 26649287},
#    {'date': '2018-05-25',
#     'open': 98.3,
#     'high': 98.98,
#     'low': 97.86,
#     'close': 98.36,
#     'volume': 18363918},
#    {'date': '2018-05-29',
#     'open': 97.84,
#     'high': 98.88,
#     'low': 97.23,
#     'close': 98.01,
#     'volume': 28670981},
#    {'date': '2018-05-30',
#     'open': 98.31,
#     'high': 99.25,
#     'low': 97.91,
#     'close': 98.95,
#     'volume': 22158528},
#    {'date': '2018-05-31',
#     'open': 99.29,
#     'high': 99.99,
#     'low': 98.61,
#     'close': 98.84,
#     'volume': 34140891},
#    {'date': '2018-06-01',
#     'open': 99.2798,
#     'high': 100.86,
#     'low': 99.17,
#     'close': 100.79,
#     'volume': 28655624},
#    {'date': '2018-06-04',
#     'open': 101.26,
#     'high': 101.86,
#     'low': 100.851,
#     'close': 101.67,
#     'volume': 27281623},
#    {'date': '2018-06-05',
#     'open': 102.0,
#     'high': 102.33,
#     'low': 101.53,
#     'close': 102.19,
#     'volume': 23514402},
#    {'date': '2018-06-06',
#     'open': 102.48,
#     'high': 102.6,
#     'low': 101.9,
#     'close': 102.49,
#     'volume': 21122917},
#    {'date': '2018-06-07',
#     'open': 102.65,
#     'high': 102.69,
#     'low': 100.38,
#     'close': 100.88,
#     'volume': 28232197},
#    {'date': '2018-06-08',
#     'open': 101.0924,
#     'high': 101.95,
#     'low': 100.54,
#     'close': 101.63,
#     'volume': 22165128},
#    {'date': '2018-06-11',
#     'open': 101.37,
#     'high': 101.59,
#     'low': 100.67,
#     'close': 101.05,
#     'volume': 23490894},
#    {'date': '2018-06-12',
#     'open': 101.1,
#     'high': 101.4493,
#     'low': 100.75,
#     'close': 101.31,
#     'volume': 18325228},
#    {'date': '2018-06-13',
#     'open': 101.72,
#     'high': 102.01,
#     'low': 100.56,
#     'close': 100.85,
#     'volume': 29492875},
#    {'date': '2018-06-14',
#     'open': 101.65,
#     'high': 102.03,
#     'low': 101.0,
#     'close': 101.42,
#     'volume': 25691811},
#    {'date': '2018-06-15',
#     'open': 101.51,
#     'high': 101.53,
#     'low': 100.07,
#     'close': 100.13,
#     'volume': 65738585},
#    {'date': '2018-06-18',
#     'open': 100.01,
#     'high': 101.11,
#     'low': 99.42,
#     'close': 100.86,
#     'volume': 23586037},
#    {'date': '2018-06-19',
#     'open': 99.65,
#     'high': 101.0,
#     'low': 99.5,
#     'close': 100.86,
#     'volume': 28653087},
#    {'date': '2018-06-20',
#     'open': 101.37,
#     'high': 102.52,
#     'low': 101.12,
#     'close': 101.87,
#     'volume': 26180792},
#    {'date': '2018-06-21',
#     'open': 102.075,
#     'high': 102.46,
#     'low': 100.88,
#     'close': 101.14,
#     'volume': 23198188},
#    {'date': '2018-06-22',
#     'open': 100.41,
#     'high': 100.77,
#     'low': 99.625,
#     'close': 100.41,
#     'volume': 38923105},
#    {'date': '2018-06-25',
#     'open': 100.0,
#     'high': 100.11,
#     'low': 97.3,
#     'close': 98.39,
#     'volume': 35433333},
#    {'date': '2018-06-26',
#     'open': 98.82,
#     'high': 100.08,
#     'low': 98.75,
#     'close': 99.08,
#     'volume': 26897244},
#    {'date': '2018-06-27',
#     'open': 99.58,
#     'high': 100.02,
#     'low': 97.4,
#     'close': 97.54,
#     'volume': 31298386},
#    {'date': '2018-06-28',
#     'open': 97.38,
#     'high': 99.11,
#     'low': 97.26,
#     'close': 98.63,
#     'volume': 26650671},
#    {'date': '2018-06-29',
#     'open': 98.93,
#     'high': 99.91,
#     'low': 98.33,
#     'close': 98.61,
#     'volume': 28053214},
#    {'date': '2018-07-02',
#     'open': 98.1,
#     'high': 100.06,
#     'low': 98.0,
#     'close': 100.01,
#     'volume': 19564521},
#    {'date': '2018-07-03',
#     'open': 100.48,
#     'high': 100.63,
#     'low': 98.94,
#     'close': 99.05,
#     'volume': 14670275},
#    {'date': '2018-07-05',
#     'open': 99.5,
#     'high': 99.92,
#     'low': 99.0299,
#     'close': 99.76,
#     'volume': 18977402},
#    {'date': '2018-07-06',
#     'open': 99.885,
#     'high': 101.43,
#     'low': 99.67,
#     'close': 101.16,
#     'volume': 19234627},
#    {'date': '2018-07-09',
#     'open': 101.6452,
#     'high': 102.25,
#     'low': 101.251,
#     'close': 101.85,
#     'volume': 18211980},
#    {'date': '2018-07-10',
#     'open': 102.0,
#     'high': 102.51,
#     'low': 101.86,
#     'close': 102.12,
#     'volume': 19293140},
#    {'date': '2018-07-11',
#     'open': 101.15,
#     'high': 102.34,
#     'low': 101.1,
#     'close': 101.98,
#     'volume': 19644648},
#    {'date': '2018-07-12',
#     'open': 102.77,
#     'high': 104.41,
#     'low': 102.73,
#     'close': 104.19,
#     'volume': 24335929},
#    {'date': '2018-07-13',
#     'open': 104.37,
#     'high': 105.6,
#     'low': 104.09,
#     'close': 105.43,
#     'volume': 24653500},
#    {'date': '2018-07-16',
#     'open': 105.4,
#     'high': 105.82,
#     'low': 104.515,
#     'close': 104.91,
#     'volume': 21786912},
#    {'date': '2018-07-17',
#     'open': 104.61,
#     'high': 106.5,
#     'low': 104.32,
#     'close': 105.95,
#     'volume': 25901726},
#    {'date': '2018-07-18',
#     'open': 105.94,
#     'high': 106.05,
#     'low': 104.715,
#     'close': 105.12,
#     'volume': 29493927},
#    {'date': '2018-07-19',
#     'open': 104.93,
#     'high': 105.31,
#     'low': 103.89,
#     'close': 104.4,
#     'volume': 40171646},
#    {'date': '2018-07-20',
#     'open': 108.08,
#     'high': 108.2,
#     'low': 106.08,
#     'close': 106.27,
#     'volume': 56038827},
#    {'date': '2018-07-23',
#     'open': 106.3,
#     'high': 108.14,
#     'low': 106.13,
#     'close': 107.97,
#     'volume': 29706955},
#    {'date': '2018-07-24',
#     'open': 108.57,
#     'high': 108.82,
#     'low': 107.26,
#     'close': 107.66,
#     'volume': 26316619},
#    {'date': '2018-07-25',
#     'open': 107.955,
#     'high': 111.15,
#     'low': 107.6,
#     'close': 110.83,
#     'volume': 30798058},
#    {'date': '2018-07-26',
#     'open': 110.74,
#     'high': 111.0,
#     'low': 109.5,
#     'close': 109.62,
#     'volume': 31372110},
#    {'date': '2018-07-27',
#     'open': 110.18,
#     'high': 110.18,
#     'low': 106.14,
#     'close': 107.68,
#     'volume': 37005292},
#    {'date': '2018-07-30',
#     'open': 107.19,
#     'high': 107.53,
#     'low': 104.76,
#     'close': 105.37,
#     'volume': 34668327},
#    {'date': '2018-07-31',
#     'open': 106.49,
#     'high': 106.72,
#     'low': 105.38,
#     'close': 106.08,
#     'volume': 27655152},
#    {'date': '2018-08-01',
#     'open': 106.03,
#     'high': 106.446,
#     'low': 105.42,
#     'close': 106.28,
#     'volume': 23628699},
#    {'date': '2018-08-02',
#     'open': 105.4,
#     'high': 108.09,
#     'low': 104.84,
#     'close': 107.57,
#     'volume': 26104258},
#    {'date': '2018-08-03',
#     'open': 107.8,
#     'high': 108.05,
#     'low': 106.82,
#     'close': 108.04,
#     'volume': 18659599},
#    {'date': '2018-08-06',
#     'open': 108.12,
#     'high': 108.42,
#     'low': 107.559,
#     'close': 108.13,
#     'volume': 20265947},
#    {'date': '2018-08-07',
#     'open': 108.56,
#     'high': 109.1,
#     'low': 108.17,
#     'close': 108.88,
#     'volume': 16080214},
#    {'date': '2018-08-08',
#     'open': 109.33,
#     'high': 109.75,
#     'low': 108.7599,
#     'close': 109.49,
#     'volume': 15487502},
#    {'date': '2018-08-09',
#     'open': 109.71,
#     'high': 110.16,
#     'low': 109.6,
#     'close': 109.67,
#     'volume': 13677211},
#    {'date': '2018-08-10',
#     'open': 109.42,
#     'high': 109.69,
#     'low': 108.38,
#     'close': 109.0,
#     'volume': 18183724},
#    {'date': '2018-08-13',
#     'open': 109.24,
#     'high': 109.58,
#     'low': 108.1,
#     'close': 108.21,
#     'volume': 18474884},
#    {'date': '2018-08-14',
#     'open': 108.56,
#     'high': 109.75,
#     'low': 108.04,
#     'close': 109.56,
#     'volume': 16788314},
#    {'date': '2018-08-15',
#     'open': 108.49,
#     'high': 108.985,
#     'low': 106.82,
#     'close': 107.66,
#     'volume': 29982806},
#    {'date': '2018-08-16',
#     'open': 108.3,
#     'high': 108.86,
#     'low': 107.3,
#     'close': 107.64,
#     'volume': 21384289},
#    {'date': '2018-08-17',
#     'open': 107.36,
#     'high': 107.9,
#     'low': 106.69,
#     'close': 107.58,
#     'volume': 18061512},
#    {'date': '2018-08-20',
#     'open': 107.51,
#     'high': 107.9,
#     'low': 106.48,
#     'close': 106.87,
#     'volume': 17914201},
#    {'date': '2018-08-21',
#     'open': 106.92,
#     'high': 107.35,
#     'low': 105.85,
#     'close': 105.98,
#     'volume': 22881861},
#    {'date': '2018-08-22',
#     'open': 105.85,
#     'high': 107.34,
#     'low': 105.78,
#     'close': 107.06,
#     'volume': 18000639},
#    {'date': '2018-08-23',
#     'open': 107.15,
#     'high': 108.18,
#     'low': 106.87,
#     'close': 107.56,
#     'volume': 18167723},
#    {'date': '2018-08-24',
#     'open': 107.67,
#     'high': 108.56,
#     'low': 107.56,
#     'close': 108.4,
#     'volume': 17234020},
#    {'date': '2018-08-27',
#     'open': 109.27,
#     'high': 109.64,
#     'low': 108.51,
#     'close': 109.6,
#     'volume': 19662331},
#    {'date': '2018-08-28',
#     'open': 109.94,
#     'high': 110.5,
#     'low': 109.79,
#     'close': 110.26,
#     'volume': 19151528},
#    {'date': '2018-08-29',
#     'open': 110.45,
#     'high': 112.03,
#     'low': 110.27,
#     'close': 112.02,
#     'volume': 20818044},
#    {'date': '2018-08-30',
#     'open': 111.67,
#     'high': 112.61,
#     'low': 111.44,
#     'close': 111.95,
#     'volume': 22798702},
#    {'date': '2018-08-31',
#     'open': 111.685,
#     'high': 112.777,
#     'low': 111.515,
#     'close': 112.33,
#     'volume': 23222713},
#    {'date': '2018-09-04',
#     'open': 110.85,
#     'high': 111.955,
#     'low': 110.22,
#     'close': 111.71,
#     'volume': 22634641},
#    {'date': '2018-09-05',
#     'open': 111.01,
#     'high': 111.42,
#     'low': 108.1,
#     'close': 108.49,
#     'volume': 32872352},
#    {'date': '2018-09-06',
#     'open': 108.25,
#     'high': 108.99,
#     'low': 107.51,
#     'close': 108.74,
#     'volume': 23477624},
#    {'date': '2018-09-07',
#     'open': 108.23,
#     'high': 108.7248,
#     'low': 107.23,
#     'close': 108.21,
#     'volume': 22498646},
#    {'date': '2018-09-10',
#     'open': 108.84,
#     'high': 109.64,
#     'low': 108.36,
#     'close': 109.38,
#     'volume': 20727906},
#    {'date': '2018-09-11',
#     'open': 108.9,
#     'high': 111.59,
#     'low': 108.89,
#     'close': 111.24,
#     'volume': 24301774},
#    {'date': '2018-09-12',
#     'open': 111.43,
#     'high': 111.85,
#     'low': 110.51,
#     'close': 111.71,
#     'volume': 18891064},
#    {'date': '2018-09-13',
#     'open': 112.12,
#     'high': 113.725,
#     'low': 112.12,
#     'close': 112.91,
#     'volume': 26055620},
#    {'date': '2018-09-14',
#     'open': 113.36,
#     'high': 113.73,
#     'low': 112.44,
#     'close': 113.37,
#     'volume': 19122349},
#    {'date': '2018-09-17',
#     'open': 113.69,
#     'high': 113.7,
#     'low': 111.86,
#     'close': 112.14,
#     'volume': 20736516},
#    {'date': '2018-09-18',
#     'open': 112.19,
#     'high': 113.695,
#     'low': 111.72,
#     'close': 113.21,
#     'volume': 22170934},
#    {'date': '2018-09-19',
#     'open': 113.05,
#     'high': 113.32,
#     'low': 111.035,
#     'close': 111.7,
#     'volume': 21728429},
#    {'date': '2018-09-20',
#     'open': 112.28,
#     'high': 113.8,
#     'low': 111.93,
#     'close': 113.57,
#     'volume': 23714512},
#    {'date': '2018-09-21',
#     'open': 114.0,
#     'high': 115.29,
#     'low': 113.51,
#     'close': 114.26,
#     'volume': 71229698},
#    {'date': '2018-09-24',
#     'open': 113.03,
#     'high': 114.9,
#     'low': 112.2175,
#     'close': 114.67,
#     'volume': 27334460},
#    {'date': '2018-09-25',
#     'open': 114.8,
#     'high': 115.1,
#     'low': 113.75,
#     'close': 114.45,
#     'volume': 22668014},
#    {'date': '2018-09-26',
#     'open': 114.47,
#     'high': 115.055,
#     'low': 113.74,
#     'close': 113.98,
#     'volume': 19352025},
#    {'date': '2018-09-27',
#     'open': 114.78,
#     'high': 114.91,
#     'low': 114.2,
#     'close': 114.41,
#     'volume': 19091299},
#    {'date': '2018-09-28',
#     'open': 114.19,
#     'high': 114.57,
#     'low': 113.68,
#     'close': 114.37,
#     'volume': 21647811},
#    {'date': '2018-10-01',
#     'open': 114.75,
#     'high': 115.68,
#     'low': 114.73,
#     'close': 115.61,
#     'volume': 18883079},
#    {'date': '2018-10-02',
#     'open': 115.3,
#     'high': 115.84,
#     'low': 114.44,
#     'close': 115.15,
#     'volume': 20787239},
#    {'date': '2018-10-03',
#     'open': 115.42,
#     'high': 116.18,
#     'low': 114.93,
#     'close': 115.17,
#     'volume': 16648018},
#    {'date': '2018-10-04',
#     'open': 114.61,
#     'high': 114.7588,
#     'low': 111.63,
#     'close': 112.79,
#     'volume': 34821717},
#    {'date': '2018-10-05',
#     'open': 112.63,
#     'high': 113.17,
#     'low': 110.64,
#     'close': 112.13,
#     'volume': 29068859},
#    {'date': '2018-10-08',
#     'open': 111.66,
#     'high': 112.03,
#     'low': 109.34,
#     'close': 110.85,
#     'volume': 29640588},
#    {'date': '2018-10-09',
#     'open': 111.14,
#     'high': 113.08,
#     'low': 110.8,
#     'close': 112.26,
#     'volume': 26198594},
#    {'date': '2018-10-10',
#     'open': 111.24,
#     'high': 111.5,
#     'low': 105.79,
#     'close': 106.16,
#     'volume': 61376315},
#    {'date': '2018-10-11',
#     'open': 105.35,
#     'high': 108.93,
#     'low': 104.2,
#     'close': 105.91,
#     'volume': 63904282},
#    {'date': '2018-10-12',
#     'open': 109.01,
#     'high': 111.24,
#     'low': 107.12,
#     'close': 109.57,
#     'volume': 47742109},
#    {'date': '2018-10-15',
#     'open': 108.91,
#     'high': 109.48,
#     'low': 106.9468,
#     'close': 107.6,
#     'volume': 32068103},
#    {'date': '2018-10-16',
#     'open': 109.54,
#     'high': 111.41,
#     'low': 108.95,
#     'close': 111.0,
#     'volume': 31610164},
#    {'date': '2018-10-17',
#     'open': 111.68,
#     'high': 111.81,
#     'low': 109.5482,
#     'close': 110.71,
#     'volume': 26548243},
#    {'date': '2018-10-18',
#     'open': 110.1,
#     'high': 110.53,
#     'low': 107.83,
#     'close': 108.5,
#     'volume': 32506192},
#    {'date': '2018-10-19',
#     'open': 108.93,
#     'high': 110.86,
#     'low': 108.21,
#     'close': 108.66,
#     'volume': 32785475},
#    {'date': '2018-10-22',
#     'open': 109.32,
#     'high': 110.54,
#     'low': 108.24,
#     'close': 109.63,
#     'volume': 26545607},
#    {'date': '2018-10-23',
#     'open': 107.77,
#     'high': 108.97,
#     'low': 105.11,
#     'close': 108.1,
#     'volume': 43770429},
#    {'date': '2018-10-24',
#     'open': 108.41,
#     'high': 108.49,
#     'low': 101.5901,
#     'close': 102.32,
#     'volume': 63897759},
#    {'date': '2018-10-25',
#     'open': 106.55,
#     'high': 109.27,
#     'low': 106.15,
#     'close': 108.3,
#     'volume': 61646819},
#    {'date': '2018-10-26',
#     'open': 105.69,
#     'high': 108.75,
#     'low': 104.76,
#     'close': 106.96,
#     'volume': 55523104},
#    {'date': '2018-10-29',
#     'open': 108.105,
#     'high': 108.7,
#     'low': 101.63,
#     'close': 103.85,
#     'volume': 55162001},
#    {'date': '2018-10-30',
#     'open': 103.66,
#     'high': 104.38,
#     'low': 100.11,
#     'close': 103.73,
#     'volume': 65350878},
#    {'date': '2018-10-31',
#     'open': 105.435,
#     'high': 108.14,
#     'low': 105.39,
#     'close': 106.81,
#     'volume': 51062383},
#    {'date': '2018-11-01',
#     'open': 107.05,
#     'high': 107.32,
#     'low': 105.53,
#     'close': 105.92,
#     'volume': 33384201},
#    {'date': '2018-11-02',
#     'open': 106.48,
#     'high': 107.32,
#     'low': 104.975,
#     'close': 106.16,
#     'volume': 37680194},
#    {'date': '2018-11-05',
#     'open': 106.37,
#     'high': 107.74,
#     'low': 105.9,
#     'close': 107.51,
#     'volume': 27922144},
#    {'date': '2018-11-06',
#     'open': 107.38,
#     'high': 108.84,
#     'low': 106.28,
#     'close': 107.72,
#     'volume': 24340248},
#    {'date': '2018-11-07',
#     'open': 109.44,
#     'high': 112.24,
#     'low': 109.4,
#     'close': 111.96,
#     'volume': 37901704},
#    {'date': '2018-11-08',
#     'open': 111.8,
#     'high': 112.21,
#     'low': 110.91,
#     'close': 111.75,
#     'volume': 25644105},
#    {'date': '2018-11-09',
#     'open': 110.85,
#     'high': 111.45,
#     'low': 108.76,
#     'close': 109.57,
#     'volume': 32039223},
#    {'date': '2018-11-12',
#     'open': 109.42,
#     'high': 109.96,
#     'low': 106.1,
#     'close': 106.87,
#     'volume': 33621807},
#    {'date': '2018-11-13',
#     'open': 107.55,
#     'high': 108.74,
#     'low': 106.64,
#     'close': 106.94,
#     'volume': 35374583},
#    {'date': '2018-11-14',
#     'open': 108.1,
#     'high': 108.26,
#     'low': 104.47,
#     'close': 104.97,
#     'volume': 39495141},
#    {'date': '2018-11-15',
#     'open': 104.99,
#     'high': 107.8,
#     'low': 103.91,
#     'close': 107.28,
#     'volume': 38505165},
#    {'date': '2018-11-16',
#     'open': 107.08,
#     'high': 108.88,
#     'low': 106.8,
#     'close': 108.29,
#     'volume': 33502121},
#    {'date': '2018-11-19',
#     'open': 108.27,
#     'high': 108.56,
#     'low': 103.55,
#     'close': 104.62,
#     'volume': 44773899},
#    {'date': '2018-11-20',
#     'open': 101.8,
#     'high': 102.97,
#     'low': 99.3528,
#     'close': 101.71,
#     'volume': 64052457},
#    {'date': '2018-11-21',
#     'open': 103.6,
#     'high': 104.43,
#     'low': 102.24,
#     'close': 103.11,
#     'volume': 28130621},
#    {'date': '2018-11-23',
#     'open': 102.17,
#     'high': 103.8099,
#     'low': 102.0,
#     'close': 103.07,
#     'volume': 13823099},
#    {'date': '2018-11-26',
#     'open': 104.79,
#     'high': 106.63,
#     'low': 104.58,
#     'close': 106.47,
#     'volume': 32336165},
#    {'date': '2018-11-27',
#     'open': 106.27,
#     'high': 107.33,
#     'low': 105.36,
#     'close': 107.14,
#     'volume': 29124486},
#    {'date': '2018-11-28',
#     'open': 107.89,
#     'high': 111.33,
#     'low': 107.86,
#     'close': 111.12,
#     'volume': 46788461},
#    {'date': '2018-11-29',
#     'open': 110.33,
#     'high': 111.115,
#     'low': 109.03,
#     'close': 110.19,
#     'volume': 28123195},
#    {'date': '2018-11-30',
#     'open': 110.7,
#     'high': 110.97,
#     'low': 109.36,
#     'close': 110.89,
#     'volume': 33665624},
#    {'date': '2018-12-03',
#     'open': 113.0,
#     'high': 113.42,
#     'low': 110.73,
#     'close': 112.09,
#     'volume': 34732772},
#    {'date': '2018-12-04',
#     'open': 111.94,
#     'high': 112.6373,
#     'low': 108.2115,
#     'close': 108.52,
#     'volume': 45196984},
#    {'date': '2018-12-06',
#     'open': 105.82,
#     'high': 109.24,
#     'low': 105.0,
#     'close': 109.19,
#     'volume': 49107431},
#    {'date': '2018-12-07',
#     'open': 108.38,
#     'high': 109.45,
#     'low': 104.3,
#     'close': 104.82,
#     'volume': 45044937},
#    {'date': '2018-12-10',
#     'open': 104.8,
#     'high': 107.98,
#     'low': 103.89,
#     'close': 107.59,
#     'volume': 40801525},
#    {'date': '2018-12-11',
#     'open': 109.8,
#     'high': 110.95,
#     'low': 107.44,
#     'close': 108.59,
#     'volume': 42381947},
#    {'date': '2018-12-12',
#     'open': 110.89,
#     'high': 111.27,
#     'low': 109.04,
#     'close': 109.08,
#     'volume': 36183020},
#    {'date': '2018-12-13',
#     'open': 109.58,
#     'high': 110.87,
#     'low': 108.63,
#     'close': 109.45,
#     'volume': 31333362},
#    {'date': '2018-12-14',
#     'open': 108.25,
#     'high': 109.26,
#     'low': 105.5,
#     'close': 106.03,
#     'volume': 47043136},
#    {'date': '2018-12-17',
#     'open': 105.41,
#     'high': 105.8,
#     'low': 101.71,
#     'close': 102.89,
#     'volume': 56957314},
#    {'date': '2018-12-18',
#     'open': 103.75,
#     'high': 104.51,
#     'low': 102.52,
#     'close': 103.97,
#     'volume': 49319196},
#    {'date': '2018-12-19',
#     'open': 103.65,
#     'high': 106.88,
#     'low': 101.35,
#     'close': 103.69,
#     'volume': 68198186},
#    {'date': '2018-12-20',
#     'open': 103.05,
#     'high': 104.31,
#     'low': 98.78,
#     'close': 101.51,
#     'volume': 70334184},
#    {'date': '2018-12-21',
#     'open': 101.63,
#     'high': 103.0,
#     'low': 97.46,
#     'close': 98.23,
#     'volume': 111242070},
#    {'date': '2018-12-24',
#     'open': 97.68,
#     'high': 97.97,
#     'low': 93.98,
#     'close': 94.13,
#     'volume': 43935192},
#    {'date': '2018-12-26',
#     'open': 95.14,
#     'high': 100.69,
#     'low': 93.96,
#     'close': 100.56,
#     'volume': 51634793},
#    {'date': '2018-12-27',
#     'open': 99.3,
#     'high': 101.19,
#     'low': 96.4,
#     'close': 101.18,
#     'volume': 49498509},
#    {'date': '2018-12-28',
#     'open': 102.09,
#     'high': 102.41,
#     'low': 99.52,
#     'close': 100.39,
#     'volume': 38169312},
#    {'date': '2018-12-31',
#     'open': 101.29,
#     'high': 102.4,
#     'low': 100.44,
#     'close': 101.57,
#     'volume': 33173765},
#    {'date': '2019-01-02',
#     'open': 99.55,
#     'high': 101.75,
#     'low': 98.94,
#     'close': 101.12,
#     'volume': 35329345},
#    {'date': '2019-01-03',
#     'open': 100.1,
#     'high': 100.185,
#     'low': 97.2,
#     'close': 97.4,
#     'volume': 42578410},
#    {'date': '2019-01-04',
#     'open': 99.72,
#     'high': 102.51,
#     'low': 98.93,
#     'close': 101.93,
#     'volume': 44060620},
#    {'date': '2019-01-07',
#     'open': 101.64,
#     'high': 103.2681,
#     'low': 100.98,
#     'close': 102.06,
#     'volume': 35656136},
#    {'date': '2019-01-08',
#     'open': 103.04,
#     'high': 103.97,
#     'low': 101.7134,
#     'close': 102.8,
#     'volume': 31514415},
#    {'date': '2019-01-09',
#     'open': 103.86,
#     'high': 104.88,
#     'low': 103.2445,
#     'close': 104.27,
#     'volume': 32280840},
#    {'date': '2019-01-10',
#     'open': 103.22,
#     'high': 103.75,
#     'low': 102.38,
#     'close': 103.6,
#     'volume': 30067556},
#    {'date': '2019-01-11',
#     'open': 103.19,
#     'high': 103.44,
#     'low': 101.64,
#     'close': 102.8,
#     'volume': 28314202},
#    {'date': '2019-01-14',
#     'open': 101.9,
#     'high': 102.8716,
#     'low': 101.26,
#     'close': 102.05,
#     'volume': 28437079},
#    {'date': '2019-01-15',
#     'open': 102.51,
#     'high': 105.05,
#     'low': 101.88,
#     'close': 105.01,
#     'volume': 31587616},
#    {'date': '2019-01-16',
#     'open': 105.26,
#     'high': 106.255,
#     'low': 104.96,
#     'close': 105.38,
#     'volume': 29853865},
#    {'date': '2019-01-17',
#     'open': 105.0,
#     'high': 106.625,
#     'low': 104.76,
#     'close': 106.12,
#     'volume': 28393015},
#    {'date': '2019-01-18',
#     'open': 107.46,
#     'high': 107.9,
#     'low': 105.91,
#     'close': 107.71,
#     'volume': 37427587},
#    {'date': '2019-01-22',
#     'open': 106.75,
#     'high': 107.1,
#     'low': 104.86,
#     'close': 105.68,
#     'volume': 32371253},
#    {'date': '2019-01-23',
#     'open': 106.12,
#     'high': 107.04,
#     'low': 105.34,
#     'close': 106.71,
#     'volume': 25874294},
#    {'date': '2019-01-24',
#     'open': 106.86,
#     'high': 107.0,
#     'low': 105.34,
#     'close': 106.2,
#     'volume': 23164838},
#    {'date': '2019-01-25',
#     'open': 107.24,
#     'high': 107.88,
#     'low': 106.59,
#     'close': 107.17,
#     'volume': 31218193},
#    {'date': '2019-01-28',
#     'open': 106.26,
#     'high': 106.48,
#     'low': 104.66,
#     'close': 105.08,
#     'volume': 29476719},
#    {'date': '2019-01-29',
#     'open': 104.88,
#     'high': 104.97,
#     'low': 102.17,
#     'close': 102.94,
#     'volume': 31490547},
#    {'date': '2019-01-30',
#     'open': 104.62,
#     'high': 106.38,
#     'low': 104.33,
#     'close': 106.38,
#     'volume': 49471866},
#    {'date': '2019-01-31',
#     'open': 103.8,
#     'high': 105.22,
#     'low': 103.18,
#     'close': 104.43,
#     'volume': 55636391},
#    {'date': '2019-02-01',
#     'open': 103.775,
#     'high': 104.0999,
#     'low': 102.35,
#     'close': 102.78,
#     'volume': 35535690},
#    {'date': '2019-02-04',
#     'open': 102.87,
#     'high': 105.8,
#     'low': 102.77,
#     'close': 105.74,
#     'volume': 31315282},
#    {'date': '2019-02-05',
#     'open': 106.06,
#     'high': 107.27,
#     'low': 105.96,
#     'close': 107.22,
#     'volume': 27325365},
#    {'date': '2019-02-06',
#     'open': 107.0,
#     'high': 107.0,
#     'low': 105.53,
#     'close': 106.03,
#     'volume': 20609759},
#    {'date': '2019-02-07',
#     'open': 105.185,
#     'high': 105.59,
#     'low': 104.29,
#     'close': 105.27,
#     'volume': 29760697},
#    {'date': '2019-02-08',
#     'open': 104.39,
#     'high': 105.78,
#     'low': 104.2603,
#     'close': 105.67,
#     'volume': 21461093},
#    {'date': '2019-02-11',
#     'open': 106.2,
#     'high': 106.58,
#     'low': 104.965,
#     'close': 105.25,
#     'volume': 18914123},
#    {'date': '2019-02-12',
#     'open': 106.14,
#     'high': 107.14,
#     'low': 105.48,
#     'close': 106.89,
#     'volume': 25056595},
#    {'date': '2019-02-13',
#     'open': 107.5,
#     'high': 107.78,
#     'low': 106.71,
#     'close': 106.81,
#     'volume': 18394869},
#    {'date': '2019-02-14',
#     'open': 106.31,
#     'high': 107.29,
#     'low': 105.66,
#     'close': 106.9,
#     'volume': 21784703},
#    {'date': '2019-02-15',
#     'open': 107.91,
#     'high': 108.3,
#     'low': 107.3624,
#     'close': 108.22,
#     'volume': 26606886},
#    {'date': '2019-02-19',
#     'open': 107.79,
#     'high': 108.66,
#     'low': 107.78,
#     'close': 108.17,
#     'volume': 18038460},
#    {'date': '2019-02-20',
#     'open': 107.86,
#     'high': 107.94,
#     'low': 106.29,
#     'close': 107.15,
#     'volume': 21607671},
#    {'date': '2019-02-21',
#     'open': 106.9,
#     'high': 109.48,
#     'low': 106.87,
#     'close': 109.41,
#     'volume': 29063231},
#    {'date': '2019-02-22',
#     'open': 110.05,
#     'high': 111.2,
#     'low': 109.82,
#     'close': 110.97,
#     'volume': 27763218},
#    {'date': '2019-02-25',
#     'open': 111.76,
#     'high': 112.18,
#     'low': 111.26,
#     'close': 111.59,
#     'volume': 23750599},
#    {'date': '2019-02-26',
#     'open': 111.26,
#     'high': 113.24,
#     'low': 111.17,
#     'close': 112.36,
#     'volume': 21536733},
#    {'date': '2019-02-27',
#     'open': 111.69,
#     'high': 112.36,
#     'low': 110.88,
#     'close': 112.17,
#     'volume': 21487062},
#    {'date': '2019-02-28',
#     'open': 112.04,
#     'high': 112.88,
#     'low': 111.73,
#     'close': 112.03,
#     'volume': 29083934},
#    {'date': '2019-03-01',
#     'open': 112.89,
#     'high': 113.02,
#     'low': 111.665,
#     'close': 112.53,
#     'volume': 23501169},
#    {'date': '2019-03-04',
#     'open': 113.02,
#     'high': 113.25,
#     'low': 110.8,
#     'close': 112.26,
#     'volume': 26608014},
#    {'date': '2019-03-05',
#     'open': 112.25,
#     'high': 112.39,
#     'low': 111.23,
#     'close': 111.7,
#     'volume': 19538318},
#    {'date': '2019-03-06',
#     'open': 111.87,
#     'high': 112.66,
#     'low': 111.43,
#     'close': 111.75,
#     'volume': 17686996},
#    {'date': '2019-03-07',
#     'open': 111.4,
#     'high': 111.55,
#     'low': 109.865,
#     'close': 110.39,
#     'volume': 25338954},
#    {'date': '2019-03-08',
#     'open': 109.16,
#     'high': 110.71,
#     'low': 108.8,
#     'close': 110.51,
#     'volume': 22818430},
#    {'date': '2019-03-11',
#     'open': 110.99,
#     'high': 112.95,
#     'low': 110.98,
#     'close': 112.83,
#     'volume': 26491618},
#    {'date': '2019-03-12',
#     'open': 112.82,
#     'high': 113.99,
#     'low': 112.6499,
#     'close': 113.62,
#     'volume': 26132717},
#    {'date': '2019-03-13',
#     'open': 114.13,
#     'high': 115.0,
#     'low': 113.78,
#     'close': 114.5,
#     'volume': 35513771},
#    {'date': '2019-03-14',
#     'open': 114.54,
#     'high': 115.2,
#     'low': 114.33,
#     'close': 114.59,
#     'volume': 30763367},
#    {'date': '2019-03-15',
#     'open': 115.34,
#     'high': 117.25,
#     'low': 114.59,
#     'close': 115.91,
#     'volume': 54630661},
#    {'date': '2019-03-18',
#     'open': 116.17,
#     'high': 117.61,
#     'low': 116.05,
#     'close': 117.57,
#     'volume': 31207596},
#    {'date': '2019-03-19',
#     'open': 118.09,
#     'high': 118.44,
#     'low': 116.99,
#     'close': 117.65,
#     'volume': 37588697},
#    {'date': '2019-03-20',
#     'open': 117.39,
#     'high': 118.75,
#     'low': 116.71,
#     'close': 117.52,
#     'volume': 28113343},
#    {'date': '2019-03-21',
#     'open': 117.135,
#     'high': 120.82,
#     'low': 117.09,
#     'close': 120.22,
#     'volume': 29854446},
#    {'date': '2019-03-22',
#     'open': 119.5,
#     'high': 119.59,
#     'low': 117.04,
#     'close': 117.05,
#     'volume': 33624528},
#    {'date': '2019-03-25',
#     'open': 116.56,
#     'high': 118.01,
#     'low': 116.3224,
#     'close': 117.66,
#     'volume': 27067117},
#    {'date': '2019-03-26',
#     'open': 118.62,
#     'high': 118.705,
#     'low': 116.85,
#     'close': 117.91,
#     'volume': 26097665},
#    {'date': '2019-03-27',
#     'open': 117.875,
#     'high': 118.21,
#     'low': 115.5215,
#     'close': 116.77,
#     'volume': 22733427},
#    {'date': '2019-03-28',
#     'open': 117.44,
#     'high': 117.58,
#     'low': 116.13,
#     'close': 116.93,
#     'volume': 18334755},
#    {'date': '2019-03-29',
#     'open': 118.07,
#     'high': 118.32,
#     'low': 116.96,
#     'close': 117.94,
#     'volume': 25399752},
#    {'date': '2019-04-01',
#     'open': 118.95,
#     'high': 119.1085,
#     'low': 118.1,
#     'close': 119.02,
#     'volume': 22789103},
#    {'date': '2019-04-02',
#     'open': 119.06,
#     'high': 119.48,
#     'low': 118.52,
#     'close': 119.19,
#     'volume': 18142297},
#    {'date': '2019-04-03',
#     'open': 119.86,
#     'high': 120.43,
#     'low': 119.15,
#     'close': 119.97,
#     'volume': 22860744},
#    {'date': '2019-04-04',
#     'open': 120.1,
#     'high': 120.23,
#     'low': 118.38,
#     'close': 119.36,
#     'volume': 20112848},
#    {'date': '2019-04-05',
#     'open': 119.39,
#     'high': 120.23,
#     'low': 119.37,
#     'close': 119.89,
#     'volume': 15826245},
#    {'date': '2019-04-08',
#     'open': 119.81,
#     'high': 120.02,
#     'low': 118.64,
#     'close': 119.93,
#     'volume': 15116186},
#    {'date': '2019-04-09',
#     'open': 118.63,
#     'high': 119.54,
#     'low': 118.58,
#     'close': 119.28,
#     'volume': 17611981},
#    {'date': '2019-04-10',
#     'open': 119.76,
#     'high': 120.35,
#     'low': 119.54,
#     'close': 120.19,
#     'volume': 16477169},
#    {'date': '2019-04-11',
#     'open': 120.54,
#     'high': 120.85,
#     'low': 119.92,
#     'close': 120.33,
#     'volume': 14209121},
#    {'date': '2019-04-12',
#     'open': 120.64,
#     'high': 120.98,
#     'low': 120.37,
#     'close': 120.95,
#     'volume': 19745143},
#    {'date': '2019-04-15',
#     'open': 120.94,
#     'high': 121.58,
#     'low': 120.57,
#     'close': 121.05,
#     'volume': 15792572},
#    {'date': '2019-04-16',
#     'open': 121.64,
#     'high': 121.65,
#     'low': 120.1,
#     'close': 120.77,
#     'volume': 14071787},
#    {'date': '2019-04-17',
#     'open': 121.24,
#     'high': 121.85,
#     'low': 120.54,
#     'close': 121.77,
#     'volume': 19300938},
#    {'date': '2019-04-18',
#     'open': 122.19,
#     'high': 123.52,
#     'low': 121.3018,
#     'close': 123.37,
#     'volume': 27990998},
#    {'date': '2019-04-22',
#     'open': 122.62,
#     'high': 124.0,
#     'low': 122.57,
#     'close': 123.76,
#     'volume': 15648724},
#    {'date': '2019-04-23',
#     'open': 124.1,
#     'high': 125.58,
#     'low': 123.83,
#     'close': 125.44,
#     'volume': 24025521},
#    {'date': '2019-04-24',
#     'open': 125.79,
#     'high': 125.85,
#     'low': 124.52,
#     'close': 125.01,
#     'volume': 31256980},
#    {'date': '2019-04-25',
#     'open': 130.06,
#     'high': 131.37,
#     'low': 128.83,
#     'close': 129.15,
#     'volume': 38033892},
#    {'date': '2019-04-26',
#     'open': 129.7,
#     'high': 130.5152,
#     'low': 129.02,
#     'close': 129.89,
#     'volume': 23654933},
#    {'date': '2019-04-29',
#     'open': 129.9,
#     'high': 130.18,
#     'low': 129.35,
#     'close': 129.77,
#     'volume': 16324183},
#    {'date': '2019-04-30',
#     'open': 129.81,
#     'high': 130.7,
#     'low': 129.3947,
#     'close': 130.6,
#     'volume': 24166503},
#    {'date': '2019-05-01',
#     'open': 130.53,
#     'high': 130.65,
#     'low': 127.7,
#     'close': 127.88,
#     'volume': 26821692},
#    {'date': '2019-05-02',
#     'open': 127.98,
#     'high': 128.0,
#     'low': 125.52,
#     'close': 126.21,
#     'volume': 27350161},
#    {'date': '2019-05-03',
#     'open': 127.36,
#     'high': 129.43,
#     'low': 127.25,
#     'close': 128.9,
#     'volume': 24911126},
#    {'date': '2019-05-06',
#     'open': 126.39,
#     'high': 128.56,
#     'low': 126.11,
#     'close': 128.15,
#     'volume': 24239464},
#    {'date': '2019-05-07',
#     'open': 126.46,
#     'high': 127.18,
#     'low': 124.22,
#     'close': 125.52,
#     'volume': 36017661},
#    {'date': '2019-05-08',
#     'open': 125.44,
#     'high': 126.37,
#     'low': 124.75,
#     'close': 125.51,
#     'volume': 28418996},
#    {'date': '2019-05-09',
#     'open': 124.29,
#     'high': 125.79,
#     'low': 123.57,
#     'close': 125.5,
#     'volume': 27235835},
#    {'date': '2019-05-10',
#     'open': 124.91,
#     'high': 127.93,
#     'low': 123.82,
#     'close': 127.13,
#     'volume': 30915084},
#    {'date': '2019-05-13',
#     'open': 124.11,
#     'high': 125.55,
#     'low': 123.04,
#     'close': 123.35,
#     'volume': 33944923},
#    {'date': '2019-05-14',
#     'open': 123.87,
#     'high': 125.88,
#     'low': 123.7,
#     'close': 124.73,
#     'volume': 25266315},
#    {'date': '2019-05-15',
#     'open': 124.26,
#     'high': 126.71,
#     'low': 123.7,
#     'close': 126.02,
#     'volume': 24722708},
#    {'date': '2019-05-16',
#     'open': 126.75,
#     'high': 129.38,
#     'low': 126.46,
#     'close': 128.93,
#     'volume': 30112216},
#    {'date': '2019-05-17',
#     'open': 128.305,
#     'high': 130.46,
#     'low': 127.92,
#     'close': 128.07,
#     'volume': 25770539},
#    {'date': '2019-05-20',
#     'open': 126.52,
#     'high': 127.5894,
#     'low': 125.7607,
#     'close': 126.22,
#     'volume': 23706934},
#    {'date': '2019-05-21',
#     'open': 127.43,
#     'high': 127.5273,
#     'low': 126.58,
#     'close': 126.9,
#     'volume': 15293260},
#    {'date': '2019-05-22',
#     'open': 126.62,
#     'high': 128.24,
#     'low': 126.52,
#     'close': 127.67,
#     'volume': 15396485},
#    {'date': '2019-05-23',
#     'open': 126.2,
#     'high': 126.29,
#     'low': 124.74,
#     'close': 126.18,
#     'volume': 23603810},
#    {'date': '2019-05-24',
#     'open': 126.91,
#     'high': 127.415,
#     'low': 125.97,
#     'close': 126.24,
#     'volume': 14123358},
#    {'date': '2019-05-28',
#     'open': 126.98,
#     'high': 128.0,
#     'low': 126.05,
#     'close': 126.16,
#     'volume': 23128359},
#    {'date': '2019-05-29',
#     'open': 125.38,
#     'high': 125.39,
#     'low': 124.04,
#     'close': 124.94,
#     'volume': 22763140},
#    {'date': '2019-05-30',
#     'open': 125.26,
#     'high': 125.76,
#     'low': 124.78,
#     'close': 125.73,
#     'volume': 16829613},
#    {'date': '2019-05-31',
#     'open': 124.23,
#     'high': 124.615,
#     'low': 123.32,
#     'close': 123.68,
#     'volume': 26646769},
#    {'date': '2019-06-03',
#     'open': 123.85,
#     'high': 124.37,
#     'low': 119.01,
#     'close': 119.84,
#     'volume': 37983637},
#    {'date': '2019-06-04',
#     'open': 121.28,
#     'high': 123.28,
#     'low': 120.6522,
#     'close': 123.16,
#     'volume': 29382642},
#    {'date': '2019-06-05',
#     'open': 124.95,
#     'high': 125.87,
#     'low': 124.21,
#     'close': 125.83,
#     'volume': 24926140},
#    {'date': '2019-06-06',
#     'open': 126.44,
#     'high': 127.97,
#     'low': 125.6,
#     'close': 127.82,
#     'volume': 21458961},
#    {'date': '2019-06-07',
#     'open': 129.19,
#     'high': 132.25,
#     'low': 128.26,
#     'close': 131.4,
#     'volume': 33885588},
#    {'date': '2019-06-10',
#     'open': 132.4,
#     'high': 134.08,
#     'low': 132.0,
#     'close': 132.6,
#     'volume': 26477098},
#    {'date': '2019-06-11',
#     'open': 133.88,
#     'high': 134.24,
#     'low': 131.2757,
#     'close': 132.1,
#     'volume': 23913731},
#    {'date': '2019-06-12',
#     'open': 131.4,
#     'high': 131.97,
#     'low': 130.71,
#     'close': 131.49,
#     'volume': 17092464},
#    {'date': '2019-06-13',
#     'open': 131.98,
#     'high': 132.67,
#     'low': 131.56,
#     'close': 132.32,
#     'volume': 17200848},
#    {'date': '2019-06-14',
#     'open': 132.26,
#     'high': 133.79,
#     'low': 131.64,
#     'close': 132.45,
#     'volume': 17821703},
#    {'date': '2019-06-17',
#     'open': 132.63,
#     'high': 133.73,
#     'low': 132.53,
#     'close': 132.85,
#     'volume': 14517785},
#    {'date': '2019-06-18',
#     'open': 134.19,
#     'high': 135.24,
#     'low': 133.57,
#     'close': 135.16,
#     'volume': 25934458},
#    {'date': '2019-06-19',
#     'open': 135.0,
#     'high': 135.93,
#     'low': 133.81,
#     'close': 135.69,
#     'volume': 23744441},
#    {'date': '2019-06-20',
#     'open': 137.45,
#     'high': 137.66,
#     'low': 135.72,
#     'close': 136.95,
#     'volume': 33042592},
#    {'date': '2019-06-21',
#     'open': 136.58,
#     'high': 137.73,
#     'low': 136.46,
#     'close': 136.97,
#     'volume': 36727892},
# ...
#    {'date': '2019-09-12',
#     'open': 137.85,
#     'high': 138.42,
#     'low': 136.87,
#     'close': 137.52,
#     'volume': 27009981},
#    {'date': '2019-09-13',
#     'open': 137.78,
#     'high': 138.06,
#     'low': 136.57,
#     'close': 137.32,
#     'volume': 23363057},
#    {'date': '2019-09-16',
#     'open': 135.83,
#     'high': 136.7,
#     'low': 135.66,
#     'close': 136.33,
#     'volume': 16731440},
#    {'date': '2019-09-17',
#     'open': 136.96,
#     'high': 137.52,
#     'low': 136.425,
#     'close': 137.39,
#     'volume': 17976285},
#    {'date': '2019-09-18',
#     'open': 137.36,
#     'high': 138.67,
#     'low': 136.5299,
#     'close': 138.52,
#     'volume': 24473386},
#    {'date': '2019-09-19',
#     'open': 140.3,
#     'high': 142.37,
#     'low': 140.0736,
#     'close': 141.07,
#     'volume': 36095413},
#    {'date': '2019-09-20',
#     'open': 141.01,
#     'high': 141.65,
#     'low': 138.25,
#     'close': 139.44,
#     'volume': 40040766},
#    {'date': '2019-09-23',
#     'open': 139.23,
#     'high': 139.63,
#     'low': 138.44,
#     'close': 139.14,
#     'volume': 17408374},
#    {'date': '2019-09-24',
#     'open': 140.36,
#     'high': 140.69,
#     'low': 136.88,
#     'close': 137.38,
#     'volume': 30016670},
#    {'date': '2019-09-25',
#     'open': 137.5,
#     'high': 139.958,
#     'low': 136.03,
#     'close': 139.36,
#     'volume': 22544054},
#    {'date': '2019-09-26',
#     'open': 139.44,
#     'high': 140.18,
#     'low': 138.44,
#     'close': 139.54,
#     'volume': 17813512},
#    {'date': '2019-09-27',
#     'open': 140.15,
#     'high': 140.36,
#     'low': 136.645,
#     'close': 137.73,
#     'volume': 22498958},
#    {'date': '2019-09-30',
#     'open': 138.05,
#     'high': 139.215,
#     'low': 137.78,
#     'close': 139.03,
#     'volume': 18430390},
#    {'date': '2019-10-01',
#     'open': 139.66,
#     'high': 140.25,
#     'low': 137.0,
#     'close': 137.07,
#     'volume': 22581929},
#    {'date': '2019-10-02',
#     'open': 136.25,
#     'high': 136.37,
#     'low': 133.5799,
#     'close': 134.65,
#     'volume': 32001763},
#    {'date': '2019-10-03',
#     'open': 134.95,
#     'high': 136.75,
#     'low': 133.22,
#     'close': 136.28,
#     'volume': 26379798},
#    {'date': '2019-10-04',
#     'open': 136.75,
#     'high': 138.25,
#     'low': 136.42,
#     'close': 138.12,
#     'volume': 23839548},
#    {'date': '2019-10-07',
#     'open': 137.14,
#     'high': 138.18,
#     'low': 137.02,
#     'close': 137.12,
#     'volume': 16601284},
#    {'date': '2019-10-08',
#     'open': 137.08,
#     'high': 137.76,
#     'low': 135.62,
#     'close': 135.67,
#     'volume': 26783336},
#    {'date': '2019-10-09',
#     'open': 137.46,
#     'high': 138.7,
#     'low': 136.97,
#     'close': 138.24,
#     'volume': 20178482},
#    {'date': '2019-10-10',
#     'open': 138.49,
#     'high': 139.6699,
#     'low': 138.25,
#     'close': 139.1,
#     'volume': 18396605},
#    {'date': '2019-10-11',
#     'open': 140.12,
#     'high': 141.03,
#     'low': 139.5,
#     'close': 139.68,
#     'volume': 25551065},
#    {'date': '2019-10-14',
#     'open': 139.69,
#     'high': 140.29,
#     'low': 139.52,
#     'close': 139.55,
#     'volume': 13591639},
#    {'date': '2019-10-15',
#     'open': 140.06,
#     'high': 141.79,
#     'low': 139.81,
#     'close': 141.575,
#     'volume': 19917762},
#    {'date': '2019-10-16',
#     'open': 140.79,
#     'high': 140.99,
#     'low': 139.53,
#     'close': 140.41,
#     'volume': 20841687},
#    {'date': '2019-10-17',
#     'open': 140.95,
#     'high': 141.42,
#     'low': 139.02,
#     'close': 139.69,
#     'volume': 22102797},
#    {'date': '2019-10-18',
#     'open': 139.76,
#     'high': 140.0,
#     'low': 136.56,
#     'close': 137.41,
#     'volume': 32284428},
#    {'date': '2019-10-21',
#     'open': 138.45,
#     'high': 138.5,
#     'low': 137.01,
#     'close': 138.43,
#     'volume': 20716039},
#    {'date': '2019-10-22',
#     'open': 138.97,
#     'high': 140.01,
#     'low': 136.26,
#     'close': 136.37,
#     'volume': 27935270},
#    {'date': '2019-10-23',
#     'open': 136.88,
#     'high': 137.45,
#     'low': 135.61,
#     'close': 137.24,
#     'volume': 31380309},
#    {'date': '2019-10-24',
#     'open': 139.39,
#     'high': 140.42,
#     'low': 138.67,
#     'close': 139.94,
#     'volume': 37278399},
#    {'date': '2019-10-25',
#     'open': 139.34,
#     'high': 141.14,
#     'low': 139.2,
#     'close': 140.73,
#     'volume': 25959724},
#    {'date': '2019-10-28',
#     'open': 144.4,
#     'high': 145.67,
#     'low': 143.51,
#     'close': 144.19,
#     'volume': 35280137},
#    {'date': '2019-10-29',
#     'open': 144.08,
#     'high': 144.5,
#     'low': 142.65,
#     'close': 142.83,
#     'volume': 20589469},
#    {'date': '2019-10-30',
#     'open': 143.52,
#     'high': 145.0,
#     'low': 142.79,
#     'close': 144.61,
#     'volume': 18496591},
#    {'date': '2019-10-31',
#     'open': 144.9,
#     'high': 144.93,
#     'low': 142.99,
#     'close': 143.37,
#     'volume': 24605135},
#    {'date': '2019-11-01',
#     'open': 144.26,
#     'high': 144.42,
#     'low': 142.965,
#     'close': 143.72,
#     'volume': 33128366},
#    {'date': '2019-11-04',
#     'open': 144.83,
#     'high': 145.0,
#     'low': 144.16,
#     'close': 144.55,
#     'volume': 16911999},
#    {'date': '2019-11-05',
#     'open': 144.97,
#     'high': 145.02,
#     'low': 143.905,
#     'close': 144.46,
#     'volume': 18250172},
#    {'date': '2019-11-06',
#     'open': 144.37,
#     'high': 144.52,
#     'low': 143.2,
#     'close': 144.06,
#     'volume': 16575798},
#    {'date': '2019-11-07',
#     'open': 143.84,
#     'high': 144.88,
#     'low': 143.77,
#     'close': 144.26,
#     'volume': 17786715},
#    {'date': '2019-11-08',
#     'open': 143.98,
#     'high': 145.99,
#     'low': 143.76,
#     'close': 145.96,
#     'volume': 16752939},
#    {'date': '2019-11-11',
#     'open': 145.34,
#     'high': 146.42,
#     'low': 144.73,
#     'close': 146.11,
#     'volume': 14370178},
#    {'date': '2019-11-12',
#     'open': 146.28,
#     'high': 147.57,
#     'low': 146.06,
#     'close': 147.07,
#     'volume': 18648712},
#    {'date': '2019-11-13',
#     'open': 146.74,
#     'high': 147.4625,
#     'low': 146.28,
#     'close': 147.31,
#     'volume': 17444230},
#    {'date': '2019-11-14',
#     'open': 147.02,
#     'high': 148.41,
#     'low': 147.0,
#     'close': 148.06,
#     'volume': 19755100},
#    {'date': '2019-11-15',
#     'open': 148.93,
#     'high': 149.99,
#     'low': 148.27,
#     'close': 149.97,
#     'volume': 23508807},
#    {'date': '2019-11-18',
#     'open': 150.07,
#     'high': 150.55,
#     'low': 148.98,
#     'close': 150.34,
#     'volume': 21554762},
#    {'date': '2019-11-19',
#     'open': 150.88,
#     'high': 151.33,
#     'low': 150.195,
#     'close': 150.39,
#     'volume': 23960164},
#    {'date': '2019-11-20',
#     'open': 150.31,
#     'high': 150.84,
#     'low': 148.46,
#     'close': 149.62,
#     'volume': 25720060},
#    {'date': '2019-11-21',
#     'open': 149.4,
#     'high': 149.8,
#     'low': 148.501,
#     'close': 149.48,
#     'volume': 18576083},
#    {'date': '2019-11-22',
#     'open': 150.07,
#     'high': 150.3,
#     'low': 148.82,
#     'close': 149.59,
#     'volume': 15841680},
#    {'date': '2019-11-25',
#     'open': 150.0,
#     'high': 151.35,
#     'low': 149.92,
#     'close': 151.23,
#     'volume': 22428585},
#    {'date': '2019-11-26',
#     'open': 151.36,
#     'high': 152.42,
#     'low': 151.32,
#     'close': 152.03,
#     'volume': 24635100},
#    {'date': '2019-11-27',
#     'open': 152.33,
#     'high': 152.5,
#     'low': 151.52,
#     'close': 152.32,
#     'volume': 15201293},
#    {'date': '2019-11-29',
#     'open': 152.1,
#     'high': 152.3,
#     'low': 151.28,
#     'close': 151.38,
#     'volume': 11977300},
#    {'date': '2019-12-02',
#     'open': 151.81,
#     'high': 151.83,
#     'low': 148.32,
#     'close': 149.55,
#     'volume': 27473616},
#    {'date': '2019-12-03',
#     'open': 147.49,
#     'high': 149.43,
#     'low': 146.65,
#     'close': 149.31,
#     'volume': 25192145},
#    {'date': '2019-12-04',
#     'open': 150.14,
#     'high': 150.1799,
#     'low': 149.2,
#     'close': 149.85,
#     'volume': 17580617},
#    {'date': '2019-12-05',
#     'open': 150.05,
#     'high': 150.32,
#     'low': 149.48,
#     'close': 149.93,
#     'volume': 17880601},
#    {'date': '2019-12-06',
#     'open': 150.99,
#     'high': 151.87,
#     'low': 150.27,
#     'close': 151.75,
#     'volume': 16410400},
#    {'date': '2019-12-09',
#     'open': 151.07,
#     'high': 152.21,
#     'low': 150.91,
#     'close': 151.36,
#     'volume': 16741350},
#    {'date': '2019-12-10',
#     'open': 151.29,
#     'high': 151.89,
#     'low': 150.765,
#     'close': 151.13,
#     'volume': 16481060},
#    {'date': '2019-12-11',
#     'open': 151.54,
#     'high': 151.87,
#     'low': 150.33,
#     'close': 151.7,
#     'volume': 18860001},
#    {'date': '2019-12-12',
#     'open': 151.65,
#     'high': 153.44,
#     'low': 151.02,
#     'close': 153.24,
#     'volume': 24645366},
#    {'date': '2019-12-13',
#     'open': 153.0035,
#     'high': 154.89,
#     'low': 152.83,
#     'close': 154.53,
#     'volume': 23850062},
#    {'date': '2019-12-16',
#     'open': 155.11,
#     'high': 155.9,
#     'low': 154.82,
#     'close': 155.53,
#     'volume': 24152770},
#    {'date': '2019-12-17',
#     'open': 155.45,
#     'high': 155.71,
#     'low': 154.45,
#     'close': 154.69,
#     'volume': 25443527},
#    {'date': '2019-12-18',
#     'open': 154.3,
#     'high': 155.48,
#     'low': 154.18,
#     'close': 154.37,
#     'volume': 24132379},
#    {'date': '2019-12-19',
#     'open': 154.0,
#     'high': 155.77,
#     'low': 153.75,
#     'close': 155.71,
#     'volume': 25813825},
#    {'date': '2019-12-20',
#     'open': 157.35,
#     'high': 158.49,
#     'low': 156.29,
#     'close': 157.41,
#     'volume': 53599613},
#    {'date': '2019-12-23',
#     'open': 158.12,
#     'high': 158.12,
#     'low': 157.27,
#     'close': 157.41,
#     'volume': 17726283},
#    {'date': '2019-12-24',
#     'open': 157.48,
#     'high': 157.71,
#     'low': 157.115,
#     'close': 157.38,
#     'volume': 8989150},
#    {'date': '2019-12-26',
#     'open': 157.56,
#     'high': 158.73,
#     'low': 157.4,
#     'close': 158.67,
#     'volume': 14526927},
#    {'date': '2019-12-27',
#     'open': 159.45,
#     'high': 159.55,
#     'low': 158.22,
#     'close': 158.96,
#     'volume': 18414352},
#    {'date': '2019-12-30',
#     'open': 158.9865,
#     'high': 159.02,
#     'low': 156.73,
#     'close': 157.59,
#     'volume': 16356720},
#    {'date': '2019-12-31',
#     'open': 156.77,
#     'high': 157.77,
#     'low': 156.45,
#     'close': 157.7,
#     'volume': 18393383},
#    {'date': '2020-01-02',
#     'open': 158.78,
#     'high': 160.73,
#     'low': 158.33,
#     'close': 160.62,
#     'volume': 22634546},
#    {'date': '2020-01-03',
#     'open': 158.32,
#     'high': 159.945,
#     'low': 158.06,
#     'close': 158.62,
#     'volume': 21121681},
#    {'date': '2020-01-06',
#     'open': 157.08,
#     'high': 159.1,
#     'low': 156.51,
#     'close': 159.03,
#     'volume': 20826702},
#    {'date': '2020-01-07',
#     'open': 159.32,
#     'high': 159.67,
#     'low': 157.32,
#     'close': 157.58,
#     'volume': 21881740},
#    {'date': '2020-01-08',
#     'open': 158.93,
#     'high': 160.8,
#     'low': 157.9491,
#     'close': 160.09,
#     'volume': 27762026},
#    {'date': '2020-01-09',
#     'open': 161.835,
#     'high': 162.215,
#     'low': 161.03,
#     'close': 162.09,
#     'volume': 21399951},
#    {'date': '2020-01-10',
#     'open': 162.8235,
#     'high': 163.22,
#     'low': 161.18,
#     'close': 161.34,
#     'volume': 20733946},
#    {'date': '2020-01-13',
#     'open': 161.76,
#     'high': 163.31,
#     'low': 161.26,
#     'close': 163.28,
#     'volume': 21637007},
#    {'date': '2020-01-14',
#     'open': 163.39,
#     'high': 163.6,
#     'low': 161.72,
#     'close': 162.13,
#     'volume': 23500783},
#    {'date': '2020-01-15',
#     'open': 162.62,
#     'high': 163.94,
#     'low': 162.57,
#     'close': 163.18,
#     'volume': 21417871},
#    {'date': '2020-01-16',
#     'open': 164.35,
#     'high': 166.24,
#     'low': 164.03,
#     'close': 166.17,
#     'volume': 23865360},
#    {'date': '2020-01-17',
#     'open': 167.42,
#     'high': 167.4675,
#     'low': 165.43,
#     'close': 167.1,
#     'volume': 34371659},
#    {'date': '2020-01-21',
#     'open': 166.68,
#     'high': 168.19,
#     'low': 166.43,
#     'close': 166.5,
#     'volume': 29517191},
#    {'date': '2020-01-22',
#     'open': 167.4,
#     'high': 167.49,
#     'low': 165.68,
#     'close': 165.7,
#     'volume': 24138777},
#    {'date': '2020-01-23',
#     'open': 166.19,
#     'high': 166.8,
#     'low': 165.27,
#     'close': 166.72,
#     'volume': 19680766},
#    {'date': '2020-01-24',
#     'open': 167.51,
#     'high': 167.53,
#     'low': 164.45,
#     'close': 165.04,
#     'volume': 24918117},
#    {'date': '2020-01-27',
#     'open': 161.15,
#     'high': 163.375,
#     'low': 160.2,
#     'close': 162.28,
#     'volume': 32078067},
#    {'date': '2020-01-28',
#     'open': 163.78,
#     'high': 165.755,
#     'low': 163.073,
#     'close': 165.46,
#     'volume': 24899940},
#    {'date': '2020-01-29',
#     'open': 167.84,
#     'high': 168.75,
#     'low': 165.69,
#     'close': 168.04,
#     'volume': 35127771},
#    {'date': '2020-01-30',
#     'open': 174.05,
#     'high': 174.05,
#     'low': 170.79,
#     'close': 172.78,
#     'volume': 51597470},
#    {'date': '2020-01-31',
#     'open': 172.21,
#     'high': 172.4,
#     'low': 169.58,
#     'close': 170.23,
#     'volume': 36142690},
#    {'date': '2020-02-03',
#     'open': 170.43,
#     'high': 174.5,
#     'low': 170.4,
#     'close': 174.38,
#     'volume': 30149052},
#    {'date': '2020-02-04',
#     'open': 177.14,
#     'high': 180.64,
#     'low': 176.31,
#     'close': 180.12,
#     'volume': 36433339},
#    {'date': '2020-02-05',
#     'open': 184.03,
#     'high': 184.2,
#     'low': 178.4101,
#     'close': 179.9,
#     'volume': 39186324},
#    {'date': '2020-02-06',
#     'open': 180.97,
#     'high': 183.8199,
#     'low': 180.059,
#     'close': 183.63,
#     'volume': 27751381},
#    {'date': '2020-02-07',
#     'open': 182.845,
#     'high': 185.63,
#     'low': 182.48,
#     'close': 183.89,
#     'volume': 33529074},
#    {'date': '2020-02-10',
#     'open': 183.58,
#     'high': 188.84,
#     'low': 183.25,
#     'close': 188.7,
#     'volume': 35844267},
#    {'date': '2020-02-11',
#     'open': 190.65,
#     'high': 190.7,
#     'low': 183.5,
#     'close': 184.44,
#     'volume': 53159906},
#    {'date': '2020-02-12',
#     'open': 185.58,
#     'high': 185.85,
#     'low': 181.85,
#     'close': 184.71,
#     'volume': 47062921},
#    {'date': '2020-02-13',
#     'open': 183.08,
#     'high': 186.23,
#     'low': 182.872,
#     'close': 183.71,
#     'volume': 35295834},
#    {'date': '2020-02-14',
#     'open': 183.25,
#     'high': 185.41,
#     'low': 182.65,
#     'close': 185.35,
#     'volume': 23149516},
#    {'date': '2020-02-18',
#     'open': 185.605,
#     'high': 187.7,
#     'low': 185.5,
#     'close': 187.23,
#     'volume': 27853113},
#    {'date': '2020-02-19',
#     'open': 188.06,
#     'high': 188.18,
#     'low': 186.47,
#     'close': 187.28,
#     'volume': 29997471},
#    {'date': '2020-02-20',
#     'open': 186.95,
#     'high': 187.25,
#     'low': 181.1,
#     'close': 184.42,
#     'volume': 36862376},
#    {'date': '2020-02-21',
#     'open': 183.17,
#     'high': 183.5,
#     'low': 177.25,
#     'close': 178.59,
#     'volume': 48600385},
#    {'date': '2020-02-24',
#     'open': 167.77,
#     'high': 174.55,
#     'low': 163.23,
#     'close': 170.89,
#     'volume': 68311066},
#    {'date': '2020-02-25',
#     'open': 174.2,
#     'high': 174.84,
#     'low': 167.6462,
#     'close': 168.07,
#     'volume': 68073295},
#    {'date': '2020-02-26',
#     'open': 169.71,
#     'high': 173.26,
#     'low': 168.21,
#     'close': 170.17,
#     'volume': 56387148},
#    {'date': '2020-02-27',
#     'open': 163.32,
#     'high': 167.03,
#     'low': 157.98,
#     'close': 158.18,
#     'volume': 93174906},
#    {'date': '2020-02-28',
#     'open': 152.41,
#     'high': 163.71,
#     'low': 152.0,
#     'close': 162.01,
#     'volume': 97073557},
#    {'date': '2020-03-02',
#     'open': 165.31,
#     'high': 172.92,
#     'low': 162.31,
#     'close': 172.79,
#     'volume': 71030810},
#    {'date': '2020-03-03',
#     'open': 173.8,
#     'high': 175.0,
#     'low': 162.26,
#     'close': 164.51,
#     'volume': 71677019},
#    {'date': '2020-03-04',
#     'open': 168.485,
#     'high': 170.7,
#     'low': 165.62,
#     'close': 170.55,
#     'volume': 49814383},
#    {'date': '2020-03-05',
#     'open': 166.045,
#     'high': 170.87,
#     'low': 165.69,
#     'close': 166.27,
#     'volume': 47817251},
#    {'date': '2020-03-06',
#     'open': 162.61,
#     'high': 163.11,
#     'low': 156.0,
#     'close': 161.57,
#     'volume': 72821057}]}}

# %%
#Basic data collected, converted to datetime and weekday parsed

df = pd.DataFrame.from_dict(json_normalize(json_response["history"]['day']), orient='columns')

df['date'] =  pd.to_datetime(df['date'], format='%Y-%m-%d')

df['Weekday'] = df['date'].dt.day_name()

df
# Out:
#           date     open    high       low   close    volume    Weekday
# 0   2018-01-02   86.125   86.31   85.5000   85.95  22483797    Tuesday
# 1   2018-01-03   86.055   86.51   85.9700   86.35  26061439  Wednesday
# 2   2018-01-04   86.590   87.66   86.5700   87.11  21911974   Thursday
# 3   2018-01-05   87.660   88.41   87.4300   88.19  23407110     Friday
# 4   2018-01-08   88.200   88.58   87.6046   88.28  22113049     Monday
# ..         ...      ...     ...       ...     ...       ...        ...
# 543 2020-03-02  165.310  172.92  162.3100  172.79  71030810     Monday
# 544 2020-03-03  173.800  175.00  162.2600  164.51  71677019    Tuesday
# 545 2020-03-04  168.485  170.70  165.6200  170.55  49814383  Wednesday
# 546 2020-03-05  166.045  170.87  165.6900  166.27  47817251   Thursday
# 547 2020-03-06  162.610  163.11  156.0000  161.57  72821057     Friday
#
# [548 rows x 7 columns]

# %%
df['Weekday'] == 'Monday'

mon =  df['Weekday'] == 'Monday'
fri = df['Weekday'] == 'Friday'

df[mon]['open']
df[fri]['close']
# Out:
# 3       88.19
# 8       89.60
# 12      90.00
# 17      94.06
# 22      91.78
#         ...
# 528    183.89
# 533    185.35
# 537    178.59
# 542    162.01
# 547    161.57
# Name: close, Length: 112, dtype: float64
